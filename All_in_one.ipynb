# %%
import meshio
import numpy as np
from multiprocessing import Pool
import time
import functools
from queue import PriorityQueue

#from ugs import *
# Need to make sure it's installed: pip3 install line_profiler
# %load_ext line_profiler

# %%
@functools.lru_cache(maxsize=32768)
def distance(current, _next):
    # from https://stackoverflow.com/a/1401828
    if current == _next:
        return 0
    return int(np.linalg.norm(mesh.points[current]-mesh.points[_next]))

@functools.lru_cache(maxsize=183746)
def graph_neighbours(current):
    # Get the points from the cells which have the same point in them
    points = np.unique(mesh.cells['triangle'][np.where(mesh.cells['triangle']==current)[0]])
    # remove the current point from these results:
    points = points[points != current]
    
    # Get the elevation of those connected points
    elevations = mesh.point_data['Z'][points]
    # Return a list of connected points, as long as they are above sea-level
    return points[elevations >= 0]
    

def cost_search(start, travel_cost_function, max_distance=100000, graph_neighbours=graph_neighbours):
    frontier = PriorityQueue()  # The priority queue means that we can find the least cost path to continue
    frontier.put(start, 0)      # from, along any path, meaning the resulting paths should always be the least-cost
                                # path to get to that point.
    came_from = {}
    cost_so_far = {}
    dist_so_far = {}
    came_from[start] = None
    cost_so_far[start] = 0
    dist_so_far[start] = 0
    
    while not frontier.empty():
        current = frontier.get()
        for _next in graph_neighbours(current):
            # Calculate the cost of going to this new point.
            new_cost = cost_so_far[current] + travel_cost_function(current, _next)
            # Calculate the eulerian distance to this new point.
            new_dist = dist_so_far[current] + distance(current, _next)

            # The max_distance check tells the algorithm to stop once we start getting too far away from the starting point.
            if (_next not in cost_so_far or new_cost < cost_so_far[_next]) and new_dist < max_distance:
                cost_so_far[_next] = new_cost
                dist_so_far[_next] = new_dist
                priority = new_cost
                frontier.put(_next, priority)
                came_from[_next] = current

        
    return came_from, cost_so_far

def cost_search(start, travel_cost_function, max_fuel=1000, graph_neighbours=graph_neighbours):
    frontier = PriorityQueue()  # The priority queue means that we can find the least cost path to continue
    frontier.put(start, 0)      # from, along any path, meaning the resulting paths should always be the least-cost
                                # path to get to that point.
    came_from = {}
    cost_so_far = {}
    dist_so_far = {}
    came_from[start] = None
    cost_so_far[start] = 0
    dist_so_far[start] = 0
    
    while not frontier.empty():
        current = frontier.get()
        for _next in graph_neighbours(current):
            # Calculate the cost of going to this new point.
            new_cost = cost_so_far[current] + travel_cost_function(current, _next)
            # Calculate the eulerian distance to this new point.
            new_dist = dist_so_far[current] + distance(current, _next)

            # The max_distance check tells the algorithm to stop once we start getting too far away from the starting point.
            if (_next not in cost_so_far or new_cost < cost_so_far[_next]) and new_cost <= max_fuel:
                cost_so_far[_next] = new_cost
                dist_so_far[_next] = new_dist
                priority = new_cost
                frontier.put(_next, priority)
                came_from[_next] = current

        
    return came_from, cost_so_far, dist_so_far

def get_total_cost_for_point(start, travel_cost_function, max_distance=100000, graph_neighbours=graph_neighbours):
    came_from, cost_so_far, dist_so_far = cost_search(start, travel_cost_function, max_distance, graph_neighbours=graph_neighbours)
    
    # Find the edge nodes, and add up their costs to get the total
    total_cost = 0
    for k in came_from.keys():             # For all the points we've visited,
        if k not in came_from.values():    # Find all the points that haven't been 'came_from'
            total_cost += cost_so_far[k]
            
    return total_cost

def get_total_distance_for_all_paths_to_point(start, travel_cost_function, max_fuel=1000, graph_neighbours=graph_neighbours):
    came_from, cost_so_far, dist_so_far = cost_search(start, travel_cost_function, max_fuel, graph_neighbours=graph_neighbours)
    
    # Find the edge nodes, and add up their costs to get the total
    total_dist = 0
    for k in came_from.keys():             # For all the points we've visited,
        if k not in came_from.values():    # Find all the points that haven't been 'came_from'
            total_dist += dist_so_far[k]
            
    return total_dist

def get_from_cell(cell, travel_cost_function, max_distance=100000):
    start = cell[1]
    return get_from_point(start, travel_cost_function, max_distance)

def get_dist_from_point(point, travel_cost_function, max_fuel=1000, graph_neighbours=graph_neighbours):
    # Return a tuple of (the point id, it's cost)
    total_dist = get_total_distance_for_all_paths_to_point(point, travel_cost_function, max_fuel, graph_neighbours=graph_neighbours)
    #print(os.getpid(), distance.cache_info())
    return (point, total_dist)

def get_from_point(point, travel_cost_function, max_distance=100000, graph_neighbours=graph_neighbours):
    # Return a tuple of (the point id, it's cost)
    total_cost = get_total_cost_for_point(point, travel_cost_function, max_distance, graph_neighbours)
    #print(os.getpid(), distance.cache_info())
    return (point, total_cost)

# %%
# We need to define a way to calculate cost
@functools.lru_cache(maxsize=1048576)
def distance_with_elevation_scaled(current, _next):
    # The travel_cost can be any function, including just the distance.
    # Here, we exagerate the elevation difference, to make changing elevation more costly
    if current == _next:
        return 0
    
    z_scaling = 100.  # 100. is a random number to pick, but has quite a big impact on the resulting paths.
    
    new_current = np.append(mesh.points[current][:2], mesh.point_data['Z'][current] * z_scaling)
    new_next    = np.append(mesh.points[_next][:2],   mesh.point_data['Z'][_next]   * z_scaling)
    
    return int(np.linalg.norm(new_current - new_next))  # return as Int, just for niceness

# %%
# We need to define a way to calculate cost
@functools.lru_cache(maxsize=1048576)
def elevation_only(current, _next):
    # Only take into account elevation changes for costs
    if current == _next:
        return 0
    return int(abs(mesh.point_data['Z'][current] - mesh.point_data['Z'][_next]) + distance(current, _next)*0.004)

# %%
infile = "earth/data/globe.vtk"
outfile = "costed_globe_new.vtk"
mesh = meshio.read(infile)

max_fuel = 2500
                      # A smaller value means visiting far fewer nodes, so it speeds things up a lot

# %%
# Choose which cost function you want
travel_cost = elevation_only

# %% [markdown]
# ## Prepare input data
#
# We don't want to calculate the LEC of a point below sea-level, so here we find all the points above sea-level, so they can be used as starting points.

# %%
points_above_sealevel = np.nonzero(mesh.point_data['Z'] >= 0)[0][::-1]

# %%
print("Total starting points available: ", points_above_sealevel.shape[0])
# Out:
# Total starting points available:  183646

# %% [markdown]
# ## Prepare for parallel execution
#
# We want to use a parallel map function to calculate the cost for all points. We can make this easier by 'baking in' the parameters of a function we know, and leave only the `starting point` as a variable.

# %%
from functools import partial

# We bake in the mesh and travel_cost function into the get_from_point function
get_from_point_in_mesh = partial(get_dist_from_point, travel_cost_function = travel_cost, max_fuel = max_fuel)

# %%
#%lprun -f get_from_point_in_mesh get_from_point_in_mesh(points_above_sealevel[100])

# %%
# Now we can use the get_from_point function with only a point ID as a parameter, by going via the new get_from_point_in_mesh function
# Here we do a test, and see the output format: (point, total cost of all paths to that point)
print(travel_cost(points_above_sealevel[100], points_above_sealevel[101]))
print(get_from_point_in_mesh(points_above_sealevel[100]))
print(graph_neighbours.cache_info())
# Out:
# 26021
# (651092, 24994625)
# CacheInfo(hits=580, misses=231, maxsize=183746, currsize=231)

# %%
# Output data variables
all_costs = []
mesh.point_data['cost'] = np.zeros_like(mesh.point_data['Z'])

p = Pool(6)
start = 0
inc = 1000
stop = inc

while start < points_above_sealevel.shape[0]:
    start_time = time.time()
    # Here we use a parallel map function to send out the chunk across the CPUs in the Pool
    costs = p.map(get_from_point_in_mesh, points_above_sealevel[start:stop])
    print("From ", start, " to ", stop, " took ", time.time() - start_time, "seconds, starting with point", points_above_sealevel[start], ". Percent complete: ", 100*(float(stop)/points_above_sealevel.shape[0]))
    # Save the data
    all_costs.extend(costs)
    
    # Write out data progressively, so we can see progress in Paraview
    for i in all_costs:
        mesh.point_data['cost'][i[0]] = i[1]
    meshio.write(outfile, mesh)
    
    # move to the next chunk of data
    start += inc
    stop += inc
    if stop >= points_above_sealevel.shape[0]:
        stop = points_above_sealevel.shape[0]-1
# Out:
# From  0  to  1000  took  258.11433601379395 seconds, starting with point 655344 . Percent complete:  0.5445258813151389
# From  1000  to  2000  took  143.36398315429688 seconds, starting with point 644591 . Percent complete:  1.0890517626302778
# From  2000  to  3000  took  141.87588477134705 seconds, starting with point 637313 . Percent complete:  1.6335776439454168
# From  3000  to  4000  took  156.11566472053528 seconds, starting with point 633836 . Percent complete:  2.1781035252605556
# From  4000  to  5000  took  103.78504371643066 seconds, starting with point 629731 . Percent complete:  2.722629406575695
# From  5000  to  6000  took  125.40420818328857 seconds, starting with point 628123 . Percent complete:  3.2671552878908336
# From  6000  to  7000  took  86.1420795917511 seconds, starting with point 624947 . Percent complete:  3.8116811692059724
# From  7000  to  8000  took  139.74660301208496 seconds, starting with point 623947 . Percent complete:  4.356207050521111
# From  8000  to  9000  took  159.29081463813782 seconds, starting with point 622557 . Percent complete:  4.90073293183625
# From  9000  to  10000  took  120.91468906402588 seconds, starting with point 618572 . Percent complete:  5.44525881315139
# From  10000  to  11000  took  104.73866057395935 seconds, starting with point 613811 . Percent complete:  5.989784694466528
# From  11000  to  12000  took  119.27599835395813 seconds, starting with point 612582 . Percent complete:  6.534310575781667
# From  12000  to  13000  took  80.91203665733337 seconds, starting with point 611241 . Percent complete:  7.078836457096806
# From  13000  to  14000  took  86.10769009590149 seconds, starting with point 608430 . Percent complete:  7.623362338411945
# From  14000  to  15000  took  100.88985776901245 seconds, starting with point 601476 . Percent complete:  8.167888219727084
# From  15000  to  16000  took  84.50751495361328 seconds, starting with point 598974 . Percent complete:  8.712414101042222
# From  16000  to  17000  took  70.82269382476807 seconds, starting with point 594183 . Percent complete:  9.25693998235736
# From  17000  to  18000  took  89.6154465675354 seconds, starting with point 592855 . Percent complete:  9.8014658636725
# From  18000  to  19000  took  70.1268904209137 seconds, starting with point 591419 . Percent complete:  10.34599174498764
# From  19000  to  20000  took  91.0123553276062 seconds, starting with point 587169 . Percent complete:  10.89051762630278
# From  20000  to  21000  took  65.81744956970215 seconds, starting with point 584630 . Percent complete:  11.435043507617918
# From  21000  to  22000  took  62.61424398422241 seconds, starting with point 578330 . Percent complete:  11.979569388933056
# From  22000  to  23000  took  53.57007551193237 seconds, starting with point 572751 . Percent complete:  12.524095270248194
# From  88000  to  89000  took  16.308298349380493 seconds, starting with point 335519 . Percent complete:  48.46280343704736
# From  89000  to  90000  took  15.586618661880493 seconds, starting with point 332614 . Percent complete:  49.0073293183625
# From  90000  to  91000  took  16.803253412246704 seconds, starting with point 330507 . Percent complete:  49.55185519967764
# From  91000  to  92000  took  19.07173991203308 seconds, starting with point 328534 . Percent complete:  50.09638108099278
# From  92000  to  93000  took  17.923110485076904 seconds, starting with point 325588 . Percent complete:  50.640906962307916
# From  93000  to  94000  took  19.560457468032837 seconds, starting with point 322179 . Percent complete:  51.185432843623055
# From  94000  to  95000  took  14.361095905303955 seconds, starting with point 318663 . Percent complete:  51.7299587249382
# From  95000  to  96000  took  17.10622811317444 seconds, starting with point 315147 . Percent complete:  52.27448460625334
# From  96000  to  97000  took  16.003084659576416 seconds, starting with point 312557 . Percent complete:  52.81901048756848
# From  97000  to  98000  took  15.284829139709473 seconds, starting with point 307395 . Percent complete:  53.363536368883615
# From  98000  to  99000  took  18.34982681274414 seconds, starting with point 304354 . Percent complete:  53.90806225019875
# From  99000  to  100000  took  13.718061447143555 seconds, starting with point 300822 . Percent complete:  54.45258813151389
# From  100000  to  101000  took  17.52078890800476 seconds, starting with point 297990 . Percent complete:  54.99711401282903
# From  101000  to  102000  took  15.322547912597656 seconds, starting with point 293349 . Percent complete:  55.54163989414417
# From  102000  to  103000  took  20.662745714187622 seconds, starting with point 290351 . Percent complete:  56.08616577545931
# From  103000  to  104000  took  14.079989194869995 seconds, starting with point 286632 . Percent complete:  56.630691656774445
# From  104000  to  105000  took  22.825196743011475 seconds, starting with point 282215 . Percent complete:  57.17521753808958
# From  105000  to  106000  took  14.667625904083252 seconds, starting with point 277006 . Percent complete:  57.71974341940472
# From  106000  to  107000  took  16.891249418258667 seconds, starting with point 274586 . Percent complete:  58.26426930071986
# From  107000  to  108000  took  15.854178428649902 seconds, starting with point 272694 . Percent complete:  58.808795182035
# From  108000  to  109000  took  15.13636589050293 seconds, starting with point 269666 . Percent complete:  59.35332106335014
# From  109000  to  110000  took  14.872477054595947 seconds, starting with point 266107 . Percent complete:  59.897846944665275
# From  110000  to  111000  took  13.796959400177002 seconds, starting with point 262368 . Percent complete:  60.442372825980414
# From  111000  to  112000  took  14.847492456436157 seconds, starting with point 258455 . Percent complete:  60.98689870729556
# From  112000  to  113000  took  14.710540533065796 seconds, starting with point 255558 . Percent complete:  61.5314245886107
# From  113000  to  114000  took  14.5066237449646 seconds, starting with point 250465 . Percent complete:  62.075950469925836
# From  114000  to  115000  took  14.466367244720459 seconds, starting with point 244729 . Percent complete:  62.620476351240974
# From  115000  to  116000  took  15.92301058769226 seconds, starting with point 242331 . Percent complete:  63.16500223255611
# From  116000  to  117000  took  15.26941442489624 seconds, starting with point 240180 . Percent complete:  63.70952811387125
# From  117000  to  118000  took  18.38319993019104 seconds, starting with point 236657 . Percent complete:  64.25405399518638
# From  118000  to  119000  took  16.75333571434021 seconds, starting with point 233578 . Percent complete:  64.79857987650152
# From  119000  to  120000  took  16.666161060333252 seconds, starting with point 230456 . Percent complete:  65.34310575781667
# From  120000  to  121000  took  15.87436318397522 seconds, starting with point 227770 . Percent complete:  65.88763163913181
# From  154000  to  155000  took  13.959724187850952 seconds, starting with point 103605 . Percent complete:  84.40151160384653
# From  155000  to  156000  took  15.02166199684143 seconds, starting with point 100973 . Percent complete:  84.94603748516167
# From  156000  to  157000  took  15.374849081039429 seconds, starting with point 97722 . Percent complete:  85.4905633664768
# From  157000  to  158000  took  14.992862462997437 seconds, starting with point 93947 . Percent complete:  86.03508924779194
# From  158000  to  159000  took  13.050519466400146 seconds, starting with point 91277 . Percent complete:  86.5796151291071
# From  159000  to  160000  took  12.954278707504272 seconds, starting with point 86576 . Percent complete:  87.12414101042224
# From  160000  to  161000  took  15.14931344985962 seconds, starting with point 82275 . Percent complete:  87.66866689173737
# From  161000  to  162000  took  15.205320596694946 seconds, starting with point 80138 . Percent complete:  88.21319277305251
# From  162000  to  163000  took  14.624987125396729 seconds, starting with point 76719 . Percent complete:  88.75771865436765
# From  163000  to  164000  took  15.138897180557251 seconds, starting with point 73190 . Percent complete:  89.30224453568279
# From  164000  to  165000  took  14.251807451248169 seconds, starting with point 69534 . Percent complete:  89.84677041699793
# From  165000  to  166000  took  13.559422969818115 seconds, starting with point 66423 . Percent complete:  90.39129629831307
# From  166000  to  167000  took  13.98492980003357 seconds, starting with point 62388 . Percent complete:  90.9358221796282
# From  167000  to  168000  took  15.833517074584961 seconds, starting with point 58558 . Percent complete:  91.48034806094334
# From  168000  to  169000  took  16.23061203956604 seconds, starting with point 55581 . Percent complete:  92.02487394225848
# From  169000  to  170000  took  16.607162714004517 seconds, starting with point 52033 . Percent complete:  92.56939982357362
# From  170000  to  171000  took  15.343242645263672 seconds, starting with point 48475 . Percent complete:  93.11392570488876
# From  171000  to  172000  took  18.037688732147217 seconds, starting with point 44880 . Percent complete:  93.6584515862039
# From  172000  to  173000  took  15.06942892074585 seconds, starting with point 41500 . Percent complete:  94.20297746751903
# From  173000  to  174000  took  15.612559080123901 seconds, starting with point 36349 . Percent complete:  94.74750334883417
# From  174000  to  175000  took  16.172996282577515 seconds, starting with point 33763 . Percent complete:  95.29202923014931
# From  175000  to  176000  took  15.331486225128174 seconds, starting with point 30488 . Percent complete:  95.83655511146445
# From  176000  to  177000  took  15.638031482696533 seconds, starting with point 26910 . Percent complete:  96.38108099277959
# From  177000  to  178000  took  15.056570291519165 seconds, starting with point 23563 . Percent complete:  96.92560687409473
# From  178000  to  179000  took  16.453455209732056 seconds, starting with point 19617 . Percent complete:  97.47013275540986
# From  179000  to  180000  took  16.9396812915802 seconds, starting with point 16594 . Percent complete:  98.014658636725
# From  180000  to  181000  took  17.13844871520996 seconds, starting with point 13017 . Percent complete:  98.55918451804014
# From  181000  to  182000  took  18.259713888168335 seconds, starting with point 8749 . Percent complete:  99.10371039935528
# From  182000  to  183000  took  18.35272789001465 seconds, starting with point 5911 . Percent complete:  99.64823628067042
# From  183000  to  183645  took  13.430086612701416 seconds, starting with point 2122 . Percent complete:  99.99945547411868

# %% [markdown]
# ## Output
#
# Show some of the results:

# %%
print all_costs[:100]
# Out:
#   File "<ipython-input-13-5d2897a31d53>", line 1
#     print all_costs[:100]
#                   ^
# SyntaxError: Missing parentheses in call to 'print'
