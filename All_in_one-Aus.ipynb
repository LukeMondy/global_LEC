# %%
import meshio
import numpy as np
from multiprocessing import Pool
import time
import functools
from queue import PriorityQueue

#from ugs import *
# Need to make sure it's installed: pip3 install line_profiler
# %load_ext line_profiler

# %%
@functools.lru_cache(maxsize=32768)
def distance(current, _next):
    # from https://stackoverflow.com/a/1401828
    if current == _next:
        return 0
    return int(np.linalg.norm(mesh.points[current]-mesh.points[_next]))

@functools.lru_cache(maxsize=183746)
def graph_neighbours(current):
    # Get the points from the cells which have the same point in them
    points = np.unique(mesh.cells['triangle'][np.where(mesh.cells['triangle']==current)[0]])
    # remove the current point from these results:
    points = points[points != current]
    
    # Get the elevation of those connected points
    elevations = mesh.point_data['Z'][points]
    # Return a list of connected points, as long as they are above sea-level
    return points[elevations >= 0]
    

def cost_search(start, travel_cost_function, max_distance=100000, graph_neighbours=graph_neighbours):
    frontier = PriorityQueue()  # The priority queue means that we can find the least cost path to continue
    frontier.put(start, 0)      # from, along any path, meaning the resulting paths should always be the least-cost
                                # path to get to that point.
    came_from = {}
    cost_so_far = {}
    dist_so_far = {}
    came_from[start] = None
    cost_so_far[start] = 0
    dist_so_far[start] = 0
    
    while not frontier.empty():
        current = frontier.get()
        for _next in graph_neighbours(current):
            # Calculate the cost of going to this new point.
            new_cost = cost_so_far[current] + travel_cost_function(current, _next)
            # Calculate the eulerian distance to this new point.
            new_dist = dist_so_far[current] + distance(current, _next)

            # The max_distance check tells the algorithm to stop once we start getting too far away from the starting point.
            if (_next not in cost_so_far or new_cost < cost_so_far[_next]) and new_dist < max_distance:
                cost_so_far[_next] = new_cost
                dist_so_far[_next] = new_dist
                priority = new_cost
                frontier.put(_next, priority)
                came_from[_next] = current

        
    return came_from, cost_so_far

def cost_search(start, travel_cost_function, max_fuel=1000, graph_neighbours=graph_neighbours):
    frontier = PriorityQueue()  # The priority queue means that we can find the least cost path to continue
    frontier.put(start, 0)      # from, along any path, meaning the resulting paths should always be the least-cost
                                # path to get to that point.
    came_from = {}
    cost_so_far = {}
    dist_so_far = {}
    came_from[start] = None
    cost_so_far[start] = 0
    dist_so_far[start] = 0
    
    while not frontier.empty():
        current = frontier.get()
        for _next in graph_neighbours(current):
            # Calculate the cost of going to this new point.
            new_cost = cost_so_far[current] + travel_cost_function(current, _next)
            # Calculate the eulerian distance to this new point.
            new_dist = dist_so_far[current] + distance(current, _next)

            # The max_distance check tells the algorithm to stop once we start getting too far away from the starting point.
            if (_next not in cost_so_far or new_cost < cost_so_far[_next]) and new_cost <= max_fuel:
                cost_so_far[_next] = new_cost
                dist_so_far[_next] = new_dist
                priority = new_cost
                frontier.put(_next, priority)
                came_from[_next] = current

        
    return came_from, cost_so_far, dist_so_far

def get_total_cost_for_point(start, travel_cost_function, max_distance=100000, graph_neighbours=graph_neighbours):
    came_from, cost_so_far, dist_so_far = cost_search(start, travel_cost_function, max_distance, graph_neighbours=graph_neighbours)
    
    # Find the edge nodes, and add up their costs to get the total
    total_cost = 0
    for k in came_from.keys():             # For all the points we've visited,
        if k not in came_from.values():    # Find all the points that haven't been 'came_from'
            total_cost += cost_so_far[k]
            
    return total_cost

def get_total_distance_for_all_paths_to_point(start, travel_cost_function, max_fuel=1000, graph_neighbours=graph_neighbours):
    came_from, cost_so_far, dist_so_far = cost_search(start, travel_cost_function, max_fuel, graph_neighbours=graph_neighbours)
    
    # Find the edge nodes, and add up their costs to get the total
    total_dist = 0
    for k in came_from.keys():             # For all the points we've visited,
        if k not in came_from.values():    # Find all the points that haven't been 'came_from'
            total_dist += dist_so_far[k]
            
    return total_dist

def get_from_cell(cell, travel_cost_function, max_distance=100000):
    start = cell[1]
    return get_from_point(start, travel_cost_function, max_distance)

def get_dist_from_point(point, travel_cost_function, max_fuel=1000, graph_neighbours=graph_neighbours):
    # Return a tuple of (the point id, it's cost)
    total_dist = get_total_distance_for_all_paths_to_point(point, travel_cost_function, max_fuel, graph_neighbours=graph_neighbours)
    #print(os.getpid(), distance.cache_info())
    return (point, total_dist)

def get_from_point(point, travel_cost_function, max_distance=100000, graph_neighbours=graph_neighbours):
    # Return a tuple of (the point id, it's cost)
    total_cost = get_total_cost_for_point(point, travel_cost_function, max_distance, graph_neighbours)
    #print(os.getpid(), distance.cache_info())
    return (point, total_cost)

# %%
# We need to define a way to calculate cost
@functools.lru_cache(maxsize=1048576)
def distance_with_elevation_scaled(current, _next):
    # The travel_cost can be any function, including just the distance.
    # Here, we exagerate the elevation difference, to make changing elevation more costly
    if current == _next:
        return 0
    
    z_scaling = 100.  # 100. is a random number to pick, but has quite a big impact on the resulting paths.
    
    new_current = np.append(mesh.points[current][:2], mesh.point_data['Z'][current] * z_scaling)
    new_next    = np.append(mesh.points[_next][:2],   mesh.point_data['Z'][_next]   * z_scaling)
    
    return int(np.linalg.norm(new_current - new_next))  # return as Int, just for niceness

# %%
# We need to define a way to calculate cost
@functools.lru_cache(maxsize=1048576)
def elevation_only(current, _next):
    # Only take into account elevation changes for costs
    if current == _next:
        return 0
    return int(abs(mesh.point_data['Z'][current] - mesh.point_data['Z'][_next]) + distance(current, _next)*0.005)

# %%
infile = "australia/data/AUS.vtk"
outfile = "costed_aus_new.vtk"
mesh = meshio.read(infile)

max_fuel = 1500
                      # A smaller value means visiting far fewer nodes, so it speeds things up a lot

# %%
# Choose which cost function you want
travel_cost = elevation_only

# %% [markdown]
# ## Prepare input data
#
# We don't want to calculate the LEC of a point below sea-level, so here we find all the points above sea-level, so they can be used as starting points.

# %%
points_above_sealevel = np.nonzero(mesh.point_data['Z'] >= 0)[0][::-1]

# %%
print("Total starting points available: ", points_above_sealevel.shape[0])
# Out:
# Total starting points available:  138726

# %% [markdown]
# ## Prepare for parallel execution
#
# We want to use a parallel map function to calculate the cost for all points. We can make this easier by 'baking in' the parameters of a function we know, and leave only the `starting point` as a variable.

# %%
from functools import partial

# We bake in the mesh and travel_cost function into the get_from_point function
get_from_point_in_mesh = partial(get_dist_from_point, travel_cost_function = travel_cost, max_fuel = max_fuel)

# %%
#%lprun -f get_from_point_in_mesh get_from_point_in_mesh(points_above_sealevel[100])

# %%
# Now we can use the get_from_point function with only a point ID as a parameter, by going via the new get_from_point_in_mesh function
# Here we do a test, and see the output format: (point, total cost of all paths to that point)
print(travel_cost(points_above_sealevel[100], points_above_sealevel[101]))
print(get_from_point_in_mesh(points_above_sealevel[100]))
print(graph_neighbours.cache_info())
# Out:
# 2938
# (183253, 134578594)
# CacheInfo(hits=58824, misses=3045, maxsize=183746, currsize=3045)

# %%
# Output data variables
all_costs = []
mesh.point_data['cost'] = np.zeros_like(mesh.point_data['Z'])

p = Pool(6)
start = 0
inc = 500
stop = inc

while start < points_above_sealevel.shape[0]-1:
    start_time = time.time()
    # Here we use a parallel map function to send out the chunk across the CPUs in the Pool
    costs = p.map(get_from_point_in_mesh, points_above_sealevel[start:stop])
    print("From ", start, " to ", stop, " took ", time.time() - start_time, "seconds, starting with point", points_above_sealevel[start], ". Percent complete: ", 100*(float(stop)/points_above_sealevel.shape[0]))
    # Save the data
    all_costs.extend(costs)
    
    # Write out data progressively, so we can see progress in Paraview
    for i in all_costs:
        mesh.point_data['cost'][i[0]] = i[1]
    meshio.write(outfile, mesh)
    
    # move to the next chunk of data
    start += inc
    stop += inc
    if stop >= points_above_sealevel.shape[0]:
        stop = points_above_sealevel.shape[0]-1
# Out:
# From  0  to  500  took  116.03642845153809 seconds, starting with point 183353 . Percent complete:  0.3604227037469544
# From  500  to  1000  took  77.11723923683167 seconds, starting with point 182853 . Percent complete:  0.7208454074939088
# From  1000  to  1500  took  72.68580889701843 seconds, starting with point 182353 . Percent complete:  1.0812681112408633
# From  1500  to  2000  took  75.96782803535461 seconds, starting with point 181853 . Percent complete:  1.4416908149878176
# From  2000  to  2500  took  78.21221160888672 seconds, starting with point 181353 . Percent complete:  1.802113518734772
# From  2500  to  3000  took  77.4963755607605 seconds, starting with point 180853 . Percent complete:  2.1625362224817266
# From  3000  to  3500  took  367.5736804008484 seconds, starting with point 180353 . Percent complete:  2.522958926228681
# From  3500  to  4000  took  307.77855706214905 seconds, starting with point 179787 . Percent complete:  2.883381629975635
# From  4000  to  4500  took  175.49516987800598 seconds, starting with point 179098 . Percent complete:  3.24380433372259
# From  4500  to  5000  took  151.8679609298706 seconds, starting with point 178447 . Percent complete:  3.604227037469544
# From  5000  to  5500  took  135.23548340797424 seconds, starting with point 177802 . Percent complete:  3.9646497412164985
# From  5500  to  6000  took  136.82264590263367 seconds, starting with point 177144 . Percent complete:  4.325072444963453
# From  6000  to  6500  took  136.77865767478943 seconds, starting with point 176479 . Percent complete:  4.685495148710408
# From  6500  to  7000  took  132.41701698303223 seconds, starting with point 175809 . Percent complete:  5.045917852457362
# From  7000  to  7500  took  124.39664888381958 seconds, starting with point 175137 . Percent complete:  5.4063405562043165
# From  7500  to  8000  took  128.42218136787415 seconds, starting with point 174484 . Percent complete:  5.76676325995127
# From  8000  to  8500  took  131.75929951667786 seconds, starting with point 173842 . Percent complete:  6.127185963698225
# From  8500  to  9000  took  131.27395820617676 seconds, starting with point 173175 . Percent complete:  6.48760866744518
# From  9000  to  9500  took  134.49050498008728 seconds, starting with point 172544 . Percent complete:  6.848031371192135
# From  9500  to  10000  took  116.07596445083618 seconds, starting with point 171881 . Percent complete:  7.208454074939088
# From  10000  to  10500  took  127.58920454978943 seconds, starting with point 171228 . Percent complete:  7.568876778686043
# From  10500  to  11000  took  126.21614456176758 seconds, starting with point 170577 . Percent complete:  7.929299482432997
# From  11000  to  11500  took  116.29243874549866 seconds, starting with point 169916 . Percent complete:  8.28972218617995
# From  11500  to  12000  took  131.45263719558716 seconds, starting with point 169253 . Percent complete:  8.650144889926906
# From  12000  to  12500  took  121.91426610946655 seconds, starting with point 168613 . Percent complete:  9.010567593673862
# From  12500  to  13000  took  129.3459918498993 seconds, starting with point 167967 . Percent complete:  9.370990297420816
# From  13000  to  13500  took  123.4772961139679 seconds, starting with point 167306 . Percent complete:  9.73141300116777
# From  13500  to  14000  took  125.64120268821716 seconds, starting with point 166689 . Percent complete:  10.091835704914724
# From  14000  to  14500  took  116.36823225021362 seconds, starting with point 166015 . Percent complete:  10.45225840866168
# From  14500  to  15000  took  139.04268264770508 seconds, starting with point 165337 . Percent complete:  10.812681112408633
# From  15000  to  15500  took  125.86013865470886 seconds, starting with point 164683 . Percent complete:  11.173103816155587
# From  15500  to  16000  took  123.2641441822052 seconds, starting with point 164024 . Percent complete:  11.53352651990254
# From  16000  to  16500  took  121.2846987247467 seconds, starting with point 163382 . Percent complete:  11.893949223649496
# From  16500  to  17000  took  112.10154676437378 seconds, starting with point 162729 . Percent complete:  12.25437192739645
# From  17000  to  17500  took  116.63977217674255 seconds, starting with point 162059 . Percent complete:  12.614794631143406
# From  17500  to  18000  took  113.05073952674866 seconds, starting with point 161411 . Percent complete:  12.97521733489036
# From  18000  to  18500  took  113.28334093093872 seconds, starting with point 160745 . Percent complete:  13.335640038637314
# From  18500  to  19000  took  116.7416672706604 seconds, starting with point 160081 . Percent complete:  13.69606274238427
# From  19000  to  19500  took  124.23001766204834 seconds, starting with point 159425 . Percent complete:  14.056485446131223
# From  19500  to  20000  took  114.33618187904358 seconds, starting with point 158761 . Percent complete:  14.416908149878177
# From  20000  to  20500  took  117.99653244018555 seconds, starting with point 158116 . Percent complete:  14.77733085362513
# From  20500  to  21000  took  127.63970756530762 seconds, starting with point 157466 . Percent complete:  15.137753557372086
# From  21000  to  21500  took  124.36815190315247 seconds, starting with point 156795 . Percent complete:  15.49817626111904
# From  21500  to  22000  took  128.46796011924744 seconds, starting with point 156142 . Percent complete:  15.858598964865994
# From  22000  to  22500  took  125.25647759437561 seconds, starting with point 155467 . Percent complete:  16.21902166861295
# From  22500  to  23000  took  128.47081184387207 seconds, starting with point 154837 . Percent complete:  16.5794443723599
# From  23000  to  23500  took  123.06966161727905 seconds, starting with point 154160 . Percent complete:  16.939867076106857
# From  23500  to  24000  took  123.12980103492737 seconds, starting with point 153505 . Percent complete:  17.300289779853813
# From  24000  to  24500  took  119.99544739723206 seconds, starting with point 152876 . Percent complete:  17.660712483600765
# From  24500  to  25000  took  127.23961472511292 seconds, starting with point 152207 . Percent complete:  18.021135187347724
# From  25000  to  25500  took  123.978688955307 seconds, starting with point 151567 . Percent complete:  18.381557891094676
# From  25500  to  26000  took  121.1404983997345 seconds, starting with point 150904 . Percent complete:  18.741980594841632
# From  26000  to  26500  took  129.199147939682 seconds, starting with point 150245 . Percent complete:  19.102403298588584
# From  26500  to  27000  took  131.42287015914917 seconds, starting with point 149590 . Percent complete:  19.46282600233554
# From  27000  to  27500  took  126.2249186038971 seconds, starting with point 148927 . Percent complete:  19.823248706082495
# From  27500  to  28000  took  131.73997473716736 seconds, starting with point 148275 . Percent complete:  20.183671409829447
# From  28000  to  28500  took  110.88317894935608 seconds, starting with point 147615 . Percent complete:  20.544094113576403
# From  28500  to  29000  took  120.09952545166016 seconds, starting with point 146949 . Percent complete:  20.90451681732336
# From  29000  to  29500  took  130.81213665008545 seconds, starting with point 146286 . Percent complete:  21.26493952107031
# From  29500  to  30000  took  121.27357983589172 seconds, starting with point 145630 . Percent complete:  21.625362224817266
# From  30000  to  30500  took  125.87330985069275 seconds, starting with point 144960 . Percent complete:  21.985784928564218
# From  30500  to  31000  took  131.15408062934875 seconds, starting with point 144323 . Percent complete:  22.346207632311174
# From  31000  to  31500  took  119.8930115699768 seconds, starting with point 143659 . Percent complete:  22.70663033605813
# From  31500  to  32000  took  119.10422253608704 seconds, starting with point 143017 . Percent complete:  23.06705303980508
# From  32000  to  32500  took  124.48448276519775 seconds, starting with point 142344 . Percent complete:  23.427475743552037
# From  32500  to  33000  took  132.76734733581543 seconds, starting with point 141673 . Percent complete:  23.787898447298993
# From  33000  to  33500  took  122.10139036178589 seconds, starting with point 141012 . Percent complete:  24.148321151045945
# From  33500  to  34000  took  120.23774123191833 seconds, starting with point 140361 . Percent complete:  24.5087438547929
# From  34000  to  34500  took  126.92316579818726 seconds, starting with point 139711 . Percent complete:  24.869166558539856
# From  34500  to  35000  took  124.41379570960999 seconds, starting with point 139039 . Percent complete:  25.22958926228681
# From  35000  to  35500  took  117.82445073127747 seconds, starting with point 138381 . Percent complete:  25.590011966033764
# From  35500  to  36000  took  122.15948939323425 seconds, starting with point 137718 . Percent complete:  25.95043466978072
# From  36000  to  36500  took  117.96129083633423 seconds, starting with point 137056 . Percent complete:  26.310857373527675
# From  36500  to  37000  took  126.13439798355103 seconds, starting with point 136404 . Percent complete:  26.671280077274627
# From  37000  to  37500  took  137.22139310836792 seconds, starting with point 135764 . Percent complete:  27.031702781021583
# From  37500  to  38000  took  124.48522543907166 seconds, starting with point 135068 . Percent complete:  27.39212548476854
# From  38000  to  38500  took  107.1729748249054 seconds, starting with point 134391 . Percent complete:  27.75254818851549
# From  38500  to  39000  took  120.2956645488739 seconds, starting with point 133707 . Percent complete:  28.112970892262446
# From  39000  to  39500  took  123.22856116294861 seconds, starting with point 133019 . Percent complete:  28.4733935960094
# From  39500  to  40000  took  127.58239459991455 seconds, starting with point 132351 . Percent complete:  28.833816299756354
# From  40000  to  40500  took  124.853107213974 seconds, starting with point 131693 . Percent complete:  29.19423900350331
# From  40500  to  41000  took  128.53114891052246 seconds, starting with point 131018 . Percent complete:  29.55466170725026
# From  41000  to  41500  took  132.2872486114502 seconds, starting with point 130346 . Percent complete:  29.915084410997217
# From  41500  to  42000  took  131.0401520729065 seconds, starting with point 129680 . Percent complete:  30.275507114744173
# From  42000  to  42500  took  112.03350949287415 seconds, starting with point 129009 . Percent complete:  30.635929818491125
# From  42500  to  43000  took  118.09281921386719 seconds, starting with point 128342 . Percent complete:  30.99635252223808
# From  43000  to  43500  took  119.81862258911133 seconds, starting with point 127676 . Percent complete:  31.356775225985032
# From  43500  to  44000  took  130.1689248085022 seconds, starting with point 127025 . Percent complete:  31.717197929731988
# From  44000  to  44500  took  130.60845494270325 seconds, starting with point 126366 . Percent complete:  32.07762063347894
# From  44500  to  45000  took  118.18420624732971 seconds, starting with point 125702 . Percent complete:  32.4380433372259
# From  45000  to  45500  took  120.8901379108429 seconds, starting with point 125046 . Percent complete:  32.798466040972855
# From  45500  to  46000  took  124.3808388710022 seconds, starting with point 124361 . Percent complete:  33.1588887447198
# From  46000  to  46500  took  124.60270833969116 seconds, starting with point 123686 . Percent complete:  33.51931144846676
# From  46500  to  47000  took  122.02274990081787 seconds, starting with point 123002 . Percent complete:  33.879734152213715
# From  47000  to  47500  took  117.60586142539978 seconds, starting with point 122344 . Percent complete:  34.24015685596067
# From  47500  to  48000  took  123.38613176345825 seconds, starting with point 121682 . Percent complete:  34.600579559707626
# From  48000  to  48500  took  131.03701972961426 seconds, starting with point 121020 . Percent complete:  34.961002263454574
# From  48500  to  49000  took  126.64426398277283 seconds, starting with point 120358 . Percent complete:  35.32142496720153
# From  49000  to  49500  took  125.93042778968811 seconds, starting with point 119694 . Percent complete:  35.68184767094849
# From  49500  to  50000  took  131.45299100875854 seconds, starting with point 119030 . Percent complete:  36.04227037469545
# From  50000  to  50500  took  127.23803925514221 seconds, starting with point 118359 . Percent complete:  36.4026930784424
# From  50500  to  51000  took  120.04914093017578 seconds, starting with point 117710 . Percent complete:  36.76311578218935
# From  51000  to  51500  took  126.56347012519836 seconds, starting with point 117067 . Percent complete:  37.12353848593631
# From  51500  to  52000  took  122.78115940093994 seconds, starting with point 116432 . Percent complete:  37.483961189683264
# From  52000  to  52500  took  121.12778162956238 seconds, starting with point 115781 . Percent complete:  37.84438389343022
# From  52500  to  53000  took  116.58764958381653 seconds, starting with point 115143 . Percent complete:  38.20480659717717
# From  53000  to  53500  took  120.13139748573303 seconds, starting with point 114478 . Percent complete:  38.56522930092412
# From  53500  to  54000  took  128.62439703941345 seconds, starting with point 113817 . Percent complete:  38.92565200467108
# From  54000  to  54500  took  122.64496040344238 seconds, starting with point 113134 . Percent complete:  39.286074708418035
# From  54500  to  55000  took  127.99120163917542 seconds, starting with point 112471 . Percent complete:  39.64649741216499
# From  55000  to  55500  took  126.60302948951721 seconds, starting with point 111802 . Percent complete:  40.006920115911946
# From  55500  to  56000  took  118.85037851333618 seconds, starting with point 111100 . Percent complete:  40.367342819658894
# From  56000  to  56500  took  125.02058839797974 seconds, starting with point 110475 . Percent complete:  40.72776552340585
# From  56500  to  57000  took  121.06652116775513 seconds, starting with point 109781 . Percent complete:  41.088188227152806
# From  57000  to  57500  took  122.62663102149963 seconds, starting with point 109123 . Percent complete:  41.44861093089976
# From  57500  to  58000  took  119.2099609375 seconds, starting with point 108458 . Percent complete:  41.80903363464672
# From  58000  to  58500  took  119.07955193519592 seconds, starting with point 107773 . Percent complete:  42.169456338393665
# From  58500  to  59000  took  123.42802667617798 seconds, starting with point 107095 . Percent complete:  42.52987904214062
# From  59000  to  59500  took  130.18566608428955 seconds, starting with point 106439 . Percent complete:  42.89030174588758
# From  59500  to  60000  took  127.86470222473145 seconds, starting with point 105777 . Percent complete:  43.25072444963453
# From  60000  to  60500  took  132.4424467086792 seconds, starting with point 105117 . Percent complete:  43.61114715338149
# From  60500  to  61000  took  123.51255130767822 seconds, starting with point 104429 . Percent complete:  43.971569857128436
# From  61000  to  61500  took  124.09918642044067 seconds, starting with point 103722 . Percent complete:  44.33199256087539
# From  61500  to  62000  took  117.3604691028595 seconds, starting with point 103056 . Percent complete:  44.69241526462235
# From  62500  to  63000  took  114.15031576156616 seconds, starting with point 101703 . Percent complete:  45.41326067211626
# From  63000  to  63500  took  126.03673100471497 seconds, starting with point 101043 . Percent complete:  45.773683375863214
# From  63500  to  64000  took  136.45784378051758 seconds, starting with point 100384 . Percent complete:  46.13410607961016
# From  64000  to  64500  took  129.92213559150696 seconds, starting with point 99713 . Percent complete:  46.49452878335712
# From  64500  to  65000  took  127.3049168586731 seconds, starting with point 99050 . Percent complete:  46.854951487104074
# From  65000  to  65500  took  138.31515192985535 seconds, starting with point 98401 . Percent complete:  47.21537419085103
# From  65500  to  66000  took  127.7619047164917 seconds, starting with point 97730 . Percent complete:  47.575796894597985
# From  66000  to  66500  took  116.75019407272339 seconds, starting with point 97066 . Percent complete:  47.936219598344934
# From  66500  to  67000  took  120.14269471168518 seconds, starting with point 96402 . Percent complete:  48.29664230209189
# From  67000  to  67500  took  123.45131230354309 seconds, starting with point 95734 . Percent complete:  48.657065005838845
# From  67500  to  68000  took  110.48212242126465 seconds, starting with point 95076 . Percent complete:  49.0174877095858
# From  68000  to  68500  took  132.40651035308838 seconds, starting with point 94404 . Percent complete:  49.377910413332756
# From  68500  to  69000  took  125.29912662506104 seconds, starting with point 93753 . Percent complete:  49.73833311707971
# From  69000  to  69500  took  131.6738784313202 seconds, starting with point 93056 . Percent complete:  50.09875582082667
# From  69500  to  70000  took  119.6860876083374 seconds, starting with point 92429 . Percent complete:  50.45917852457362
# From  70000  to  70500  took  115.87567567825317 seconds, starting with point 91761 . Percent complete:  50.81960122832058
# From  70500  to  71000  took  121.69624090194702 seconds, starting with point 91103 . Percent complete:  51.18002393206753
# From  71000  to  71500  took  131.59797716140747 seconds, starting with point 90439 . Percent complete:  51.54044663581448
# From  71500  to  72000  took  123.25778532028198 seconds, starting with point 89789 . Percent complete:  51.90086933956144
# From  72000  to  72500  took  121.66113519668579 seconds, starting with point 89119 . Percent complete:  52.261292043308394
# From  72500  to  73000  took  113.13911032676697 seconds, starting with point 88456 . Percent complete:  52.62171474705535
# From  73000  to  73500  took  115.82084393501282 seconds, starting with point 87802 . Percent complete:  52.982137450802306
# From  73500  to  74000  took  122.12576603889465 seconds, starting with point 87130 . Percent complete:  53.342560154549254
# From  74000  to  74500  took  121.01360559463501 seconds, starting with point 86466 . Percent complete:  53.70298285829621
# From  74500  to  75000  took  119.51957249641418 seconds, starting with point 85801 . Percent complete:  54.063405562043165
# From  75000  to  75500  took  126.66600275039673 seconds, starting with point 85170 . Percent complete:  54.42382826579012
# From  75500  to  76000  took  120.70098900794983 seconds, starting with point 84471 . Percent complete:  54.78425096953708
# From  76000  to  76500  took  128.08019137382507 seconds, starting with point 83826 . Percent complete:  55.144673673284025
# From  76500  to  77000  took  124.18513774871826 seconds, starting with point 83161 . Percent complete:  55.50509637703098
# From  77000  to  77500  took  131.62765169143677 seconds, starting with point 82508 . Percent complete:  55.865519080777936
# From  77500  to  78000  took  132.84374976158142 seconds, starting with point 81858 . Percent complete:  56.22594178452489
# From  78000  to  78500  took  125.83596348762512 seconds, starting with point 81215 . Percent complete:  56.58636448827185
# From  78500  to  79000  took  132.29759860038757 seconds, starting with point 80532 . Percent complete:  56.9467871920188
# From  79000  to  79500  took  117.75056982040405 seconds, starting with point 79878 . Percent complete:  57.30720989576575
# From  79500  to  80000  took  129.3832085132599 seconds, starting with point 79216 . Percent complete:  57.66763259951271
# From  80000  to  80500  took  126.94655561447144 seconds, starting with point 78563 . Percent complete:  58.02805530325966
# From  80500  to  81000  took  127.17043352127075 seconds, starting with point 77898 . Percent complete:  58.38847800700662
# From  81000  to  81500  took  122.43434166908264 seconds, starting with point 77243 . Percent complete:  58.748900710753574
# From  81500  to  82000  took  119.05059289932251 seconds, starting with point 76591 . Percent complete:  59.10932341450052
# From  82000  to  82500  took  119.89967012405396 seconds, starting with point 75920 . Percent complete:  59.46974611824748
# From  82500  to  83000  took  122.18576550483704 seconds, starting with point 75275 . Percent complete:  59.830168821994434
# From  83000  to  83500  took  125.9395227432251 seconds, starting with point 74610 . Percent complete:  60.19059152574139
# From  83500  to  84000  took  113.14188551902771 seconds, starting with point 73937 . Percent complete:  60.551014229488345
# From  84000  to  84500  took  126.29833674430847 seconds, starting with point 73291 . Percent complete:  60.911436933235294
# From  84500  to  85000  took  124.77626895904541 seconds, starting with point 72632 . Percent complete:  61.27185963698225
# From  85000  to  85500  took  123.08563923835754 seconds, starting with point 71987 . Percent complete:  61.632282340729205
# From  85500  to  86000  took  124.68670463562012 seconds, starting with point 71338 . Percent complete:  61.99270504447616
# From  86000  to  86500  took  128.24205327033997 seconds, starting with point 70685 . Percent complete:  62.353127748223116
# From  86500  to  87000  took  121.16526484489441 seconds, starting with point 70012 . Percent complete:  62.713550451970065
# From  87000  to  87500  took  121.88587403297424 seconds, starting with point 69359 . Percent complete:  63.07397315571702
# From  87500  to  88000  took  117.21536445617676 seconds, starting with point 68706 . Percent complete:  63.434395859463976
# From  88000  to  88500  took  123.62835836410522 seconds, starting with point 68066 . Percent complete:  63.79481856321093
# From  88500  to  89000  took  130.00732517242432 seconds, starting with point 67435 . Percent complete:  64.15524126695789
# From  89000  to  89500  took  123.86389803886414 seconds, starting with point 66798 . Percent complete:  64.51566397070484
# From  89500  to  90000  took  120.97253727912903 seconds, starting with point 66136 . Percent complete:  64.8760866744518
# From  90000  to  90500  took  110.69865584373474 seconds, starting with point 65474 . Percent complete:  65.23650937819875
# From  90500  to  91000  took  147.0714545249939 seconds, starting with point 64844 . Percent complete:  65.59693208194571
# From  91000  to  91500  took  151.98254466056824 seconds, starting with point 64181 . Percent complete:  65.95735478569266
# From  91500  to  92000  took  139.4992446899414 seconds, starting with point 63522 . Percent complete:  66.3177774894396
# From  92000  to  92500  took  155.54235816001892 seconds, starting with point 62865 . Percent complete:  66.67820019318657
# From  92500  to  93000  took  149.42771744728088 seconds, starting with point 62214 . Percent complete:  67.03862289693352
# From  93000  to  93500  took  137.76445245742798 seconds, starting with point 61554 . Percent complete:  67.39904560068048
# From  93500  to  94000  took  115.05609941482544 seconds, starting with point 60921 . Percent complete:  67.75946830442743
# From  94000  to  94500  took  125.56923341751099 seconds, starting with point 60264 . Percent complete:  68.11989100817438
# From  94500  to  95000  took  133.74757981300354 seconds, starting with point 59615 . Percent complete:  68.48031371192134
# From  95000  to  95500  took  131.46628832817078 seconds, starting with point 58973 . Percent complete:  68.84073641566829
# From  95500  to  96000  took  124.98471140861511 seconds, starting with point 58296 . Percent complete:  69.20115911941525
# From  96000  to  96500  took  128.66860055923462 seconds, starting with point 57627 . Percent complete:  69.5615818231622
# From  96500  to  97000  took  126.7469630241394 seconds, starting with point 56953 . Percent complete:  69.92200452690915
# From  97000  to  97500  took  131.97056603431702 seconds, starting with point 56279 . Percent complete:  70.28242723065611
# From  97500  to  98000  took  127.83287358283997 seconds, starting with point 55620 . Percent complete:  70.64284993440306
# From  98000  to  98500  took  125.74885559082031 seconds, starting with point 54983 . Percent complete:  71.00327263815002
# From  98500  to  99000  took  129.81576442718506 seconds, starting with point 54303 . Percent complete:  71.36369534189699
# From  99000  to  99500  took  128.23437595367432 seconds, starting with point 53646 . Percent complete:  71.72411804564393
# From  99500  to  100000  took  125.96109008789062 seconds, starting with point 52995 . Percent complete:  72.0845407493909
# From  100000  to  100500  took  131.5497488975525 seconds, starting with point 52321 . Percent complete:  72.44496345313785
# From  100500  to  101000  took  125.3981704711914 seconds, starting with point 51661 . Percent complete:  72.8053861568848
# From  101000  to  101500  took  126.64636707305908 seconds, starting with point 51005 . Percent complete:  73.16580886063176
# From  101500  to  102000  took  124.89168167114258 seconds, starting with point 50345 . Percent complete:  73.5262315643787
# From  102000  to  102500  took  118.00845289230347 seconds, starting with point 49689 . Percent complete:  73.88665426812567
# From  102500  to  103000  took  131.9352102279663 seconds, starting with point 49011 . Percent complete:  74.24707697187262
# From  103000  to  103500  took  122.06225609779358 seconds, starting with point 48351 . Percent complete:  74.60749967561956
# From  103500  to  104000  took  137.12921929359436 seconds, starting with point 47694 . Percent complete:  74.96792237936653
# From  104000  to  104500  took  135.3139786720276 seconds, starting with point 47032 . Percent complete:  75.32834508311348
# From  104500  to  105000  took  128.73770952224731 seconds, starting with point 46371 . Percent complete:  75.68876778686044
# From  105000  to  105500  took  137.270649433136 seconds, starting with point 45704 . Percent complete:  76.04919049060739
# From  105500  to  106000  took  116.15618944168091 seconds, starting with point 45029 . Percent complete:  76.40961319435434
# From  106000  to  106500  took  135.08581471443176 seconds, starting with point 44383 . Percent complete:  76.7700358981013
# From  106500  to  107000  took  124.75471663475037 seconds, starting with point 43700 . Percent complete:  77.13045860184825
# From  107000  to  107500  took  132.1303427219391 seconds, starting with point 43045 . Percent complete:  77.49088130559521
# From  107500  to  108000  took  129.77846002578735 seconds, starting with point 42390 . Percent complete:  77.85130400934216
# From  108000  to  108500  took  131.54598951339722 seconds, starting with point 41710 . Percent complete:  78.21172671308912
# From  108500  to  109000  took  135.1098608970642 seconds, starting with point 41057 . Percent complete:  78.57214941683607
# From  109000  to  109500  took  131.32851886749268 seconds, starting with point 40391 . Percent complete:  78.93257212058302
# From  109500  to  110000  took  130.31675171852112 seconds, starting with point 39745 . Percent complete:  79.29299482432998
# From  110000  to  110500  took  125.65400552749634 seconds, starting with point 39072 . Percent complete:  79.65341752807693
# From  110500  to  111000  took  121.5831401348114 seconds, starting with point 38413 . Percent complete:  80.01384023182389
# From  111000  to  111500  took  117.99433040618896 seconds, starting with point 37754 . Percent complete:  80.37426293557084
# From  111500  to  112000  took  130.15653157234192 seconds, starting with point 37088 . Percent complete:  80.73468563931779
# From  112000  to  112500  took  123.40763831138611 seconds, starting with point 36411 . Percent complete:  81.09510834306475
# From  112500  to  113000  took  128.77896857261658 seconds, starting with point 35746 . Percent complete:  81.4555310468117
# From  113000  to  113500  took  121.68959188461304 seconds, starting with point 35076 . Percent complete:  81.81595375055866
# From  113500  to  114000  took  120.39920711517334 seconds, starting with point 34418 . Percent complete:  82.17637645430561
# From  114000  to  114500  took  132.7419559955597 seconds, starting with point 33761 . Percent complete:  82.53679915805256
# From  114500  to  115000  took  130.35531163215637 seconds, starting with point 33101 . Percent complete:  82.89722186179952
# From  115000  to  115500  took  120.46837282180786 seconds, starting with point 32427 . Percent complete:  83.25764456554647
# From  115500  to  116000  took  121.83324217796326 seconds, starting with point 31748 . Percent complete:  83.61806726929343
# From  116000  to  116500  took  122.75096440315247 seconds, starting with point 31102 . Percent complete:  83.97848997304038
# From  116500  to  117000  took  126.90336751937866 seconds, starting with point 30434 . Percent complete:  84.33891267678733
# From  117000  to  117500  took  127.53003978729248 seconds, starting with point 29772 . Percent complete:  84.6993353805343
# From  117500  to  118000  took  134.06075477600098 seconds, starting with point 29112 . Percent complete:  85.05975808428124
# From  118000  to  118500  took  134.00917148590088 seconds, starting with point 28448 . Percent complete:  85.4201807880282
# From  118500  to  119000  took  126.45341610908508 seconds, starting with point 27811 . Percent complete:  85.78060349177515
# From  119000  to  119500  took  126.59778571128845 seconds, starting with point 27147 . Percent complete:  86.1410261955221
# From  119500  to  120000  took  117.85040402412415 seconds, starting with point 26505 . Percent complete:  86.50144889926906
# From  120000  to  120500  took  122.91103029251099 seconds, starting with point 25859 . Percent complete:  86.86187160301601
# From  120500  to  121000  took  122.92146682739258 seconds, starting with point 25213 . Percent complete:  87.22229430676298
# From  121000  to  121500  took  118.87914824485779 seconds, starting with point 24556 . Percent complete:  87.58271701050992
# From  121500  to  122000  took  125.31467270851135 seconds, starting with point 23895 . Percent complete:  87.94313971425687
# From  122000  to  122500  took  122.433420419693 seconds, starting with point 23231 . Percent complete:  88.30356241800384
# From  122500  to  123000  took  124.70513439178467 seconds, starting with point 22588 . Percent complete:  88.66398512175078
# From  123000  to  123500  took  134.01672530174255 seconds, starting with point 21935 . Percent complete:  89.02440782549775
# From  123500  to  124000  took  124.16424036026001 seconds, starting with point 21269 . Percent complete:  89.3848305292447
# From  124000  to  124500  took  117.57069087028503 seconds, starting with point 20613 . Percent complete:  89.74525323299164
# From  124500  to  125000  took  132.00874948501587 seconds, starting with point 19970 . Percent complete:  90.1056759367386
# From  125000  to  125500  took  128.47238063812256 seconds, starting with point 19317 . Percent complete:  90.46609864048555
# From  125500  to  126000  took  132.9384424686432 seconds, starting with point 18658 . Percent complete:  90.82652134423252
# From  126000  to  126500  took  127.79636812210083 seconds, starting with point 18003 . Percent complete:  91.18694404797947
# From  126500  to  127000  took  126.67744207382202 seconds, starting with point 17360 . Percent complete:  91.54736675172643
# From  127000  to  127500  took  125.33492279052734 seconds, starting with point 16709 . Percent complete:  91.90778945547338
# From  127500  to  128000  took  129.55422520637512 seconds, starting with point 16046 . Percent complete:  92.26821215922033
# From  128000  to  128500  took  128.87211799621582 seconds, starting with point 15384 . Percent complete:  92.62863486296729
# From  128500  to  129000  took  127.01238870620728 seconds, starting with point 14718 . Percent complete:  92.98905756671424
# From  129000  to  129500  took  124.20813536643982 seconds, starting with point 14033 . Percent complete:  93.3494802704612
# From  129500  to  130000  took  128.37329721450806 seconds, starting with point 13334 . Percent complete:  93.70990297420815
# From  130000  to  130500  took  130.30257868766785 seconds, starting with point 12680 . Percent complete:  94.0703256779551
# From  130500  to  131000  took  140.14632749557495 seconds, starting with point 12008 . Percent complete:  94.43074838170206
# From  131000  to  131500  took  131.37385725975037 seconds, starting with point 11366 . Percent complete:  94.79117108544901
# From  131500  to  132000  took  121.00893926620483 seconds, starting with point 10721 . Percent complete:  95.15159378919597
# From  132000  to  132500  took  118.8450620174408 seconds, starting with point 10074 . Percent complete:  95.51201649294292
# From  132500  to  133000  took  122.77865839004517 seconds, starting with point 9403 . Percent complete:  95.87243919668987
# From  133000  to  133500  took  123.30936241149902 seconds, starting with point 8738 . Percent complete:  96.23286190043683
# From  133500  to  134000  took  121.3681104183197 seconds, starting with point 8096 . Percent complete:  96.59328460418378
# From  134000  to  134500  took  125.12806844711304 seconds, starting with point 7455 . Percent complete:  96.95370730793074
# From  134500  to  135000  took  123.28298211097717 seconds, starting with point 6822 . Percent complete:  97.31413001167769
# From  135000  to  135500  took  129.2458119392395 seconds, starting with point 6152 . Percent complete:  97.67455271542464
# From  135500  to  136000  took  122.1272280216217 seconds, starting with point 5483 . Percent complete:  98.0349754191716
# From  136000  to  136500  took  128.85415530204773 seconds, starting with point 4829 . Percent complete:  98.39539812291855
# From  136500  to  137000  took  116.87764477729797 seconds, starting with point 4174 . Percent complete:  98.75582082666551
# From  137000  to  137500  took  132.25251579284668 seconds, starting with point 3539 . Percent complete:  99.11624353041246
# From  137500  to  138000  took  119.9079110622406 seconds, starting with point 2870 . Percent complete:  99.47666623415942
# From  138000  to  138500  took  82.11964678764343 seconds, starting with point 2243 . Percent complete:  99.83708893790639
# From  138500  to  138725  took  40.39063620567322 seconds, starting with point 1603 . Percent complete:  99.9992791545925

# %% [markdown]
# ## Output
#
# Show some of the results:

# %%
print all_costs[:100]
